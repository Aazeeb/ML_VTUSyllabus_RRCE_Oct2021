# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv("/content/drive/MyDrive/ML VTU- RRCE/sport.csv")

# %%
data
# Out:
#      sky air temp humidity    wind water forecast enjoy tennis
# 0  sunny     warm   normal  strong  warm     same          yes
# 1  sunny     warm     high  strong  warm     same          yes
# 2  rainy     cold     high  strong  warm   change           no
# 3  sunny     warm     high  strong  cool   change          yes

# %%
concepts= np.array(data)[:,:-1] #splicing the data and keeping only inputs. it is also converted to numpy array
#concepts=data.iloc[:,:-1].values
concepts
# Out:
# array([['sunny', 'warm', 'normal', 'strong', 'warm', 'same'],
#        ['sunny', 'warm', 'high', 'strong', 'warm', 'same'],
#        ['rainy', 'cold', 'high', 'strong', 'warm', 'change'],
#        ['sunny', 'warm', 'high', 'strong', 'cool', 'change']],
#       dtype=object)

# %%
target=np.array(data)[:,-1] #coverting op data to numpy array
target
# Out:
# array(['yes', 'yes', 'no', 'yes'], dtype=object)

# %%
#to understand enumerate
for i,val in enumerate(target):
  print(i)
  print(val)
# Out:
# 0
# yes
# 1
# yes
# 2
# no
# 3
# yes

# %%
def train(con,tar):
  for i,val in enumerate(tar):
    if val =='yes':
      specific_h=con[i].copy()
      break
  for i,val in enumerate(con):
    if tar[i]=='yes':
      for x in range(len(specific_h)):
        if val[x] != specific_h[x]:
          specific_h[x]='?'
        else:
          pass
  return specific_h

# %%
print(train(concepts,target))
# Out:
# ['sunny' 'warm' '?' 'strong' '?' '?']
